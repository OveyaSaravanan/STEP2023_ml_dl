# %% [markdown]
# 1.	Understand the data using python commands

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.preprocessing  import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/lung cancer.csv')
df
# Out:
#      GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      Male  69.0        1               2        2              1
# 1      Male  74.0        2               1        1              1
# 2    Female  59.0        1               1        1              2
# 3      Male  63.0        2               2        2              1
# 4    Female  63.0        1               2        1              1
# ..      ...   ...      ...             ...      ...            ...
# 304  Female  56.0        1               1        1              2
# 305    Male  70.0        2               1        1              1
# 306    Male  58.0        2               1        1              1
# 307    Male  67.0        2               1        2              1
# 308    Male  62.0        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.shape
# Out:
# (309, 16)

# %%
df.size
# Out:
# 4944

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df[['GENDER','AGE']]
# Out:
#      GENDER   AGE
# 0      Male  69.0
# 1      Male  74.0
# 2    Female  59.0
# 3      Male  63.0
# 4    Female  63.0
# ..      ...   ...
# 304  Female  56.0
# 305    Male  70.0
# 306    Male  58.0
# 307    Male  67.0
# 308    Male  62.0
#
# [309 rows x 2 columns]

# %%
df.iloc[1:2,:3]
# Out:
#   GENDER   AGE  SMOKING
# 1   Male  74.0        2

# %%
df.set_index("AGE")
# Out:
#       GENDER  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# AGE
# 69.0    Male        1               2        2              1
# 74.0    Male        2               1        1              1
# 59.0  Female        1               1        1              2
# 63.0    Male        2               2        2              1
# 63.0  Female        1               2        1              1
# ...      ...      ...             ...      ...            ...
# 56.0  Female        1               1        1              2
# 70.0    Male        2               1        1              1
# 58.0    Male        2               1        1              1
# 67.0    Male        2               1        2              1
# 62.0    Male        1               1        1              2
#
#       CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# AGE
# 69.0                1         2         1         2                  2
# ...

# %%
del df['AGE']

# %%
df
# Out:
#      GENDER  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 0      Male        1               2        2              1                1
# 1      Male        2               1        1              1                2
# 2    Female        1               1        1              2                1
# 3      Male        2               2        2              1                1
# 4    Female        1               2        1              1                1
# ..      ...      ...             ...      ...            ...              ...
# 304  Female        1               1        1              2                2
# 305    Male        2               1        1              1                1
# 306    Male        2               1        1              1                1
# 307    Male        2               1        2              1                1
# 308    Male        1               1        1              2                1
#
# ...

# %%
df.head()
# Out:
#    GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0    Male  69.0        1               2        2              1
# 1    Male  74.0        2               1        1              1
# 2  Female  59.0        1               1        1              2
# 3    Male  63.0        2               2        2              1
# 4  Female  63.0        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# ...

# %% [markdown]
# 2.	Identify the columns with missing values

# %%
df.isnull()
# Out:
#      GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0     False  False    False           False    False          False
# 1     False  False    False           False    False          False
# 2     False  False    False           False    False          False
# 3     False  False    False           False    False          False
# 4     False  False    False           False    False          False
# ..      ...    ...      ...             ...      ...            ...
# 304   False  False    False           False    False          False
# 305   False  False    False           False    False          False
# 306   False  False    False           False    False          False
# 307   False  False    False           False    False          False
# 308   False  False    False           False    False          False
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0              False     False     False     False              False
# ...

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      5
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# 3.	Fill the  missing values using any one method

# %%
df['AGE']=df['AGE'].fillna(df['AGE'].mean())

# %%
df
# Out:
#      GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      Male  69.0        1               2        2              1
# 1      Male  74.0        2               1        1              1
# 2    Female  59.0        1               1        1              2
# 3      Male  63.0        2               2        2              1
# 4    Female  63.0        1               2        1              1
# ..      ...   ...      ...             ...      ...            ...
# 304  Female  56.0        1               1        1              2
# 305    Male  70.0        2               1        1              1
# 306    Male  58.0        2               1        1              1
# 307    Male  67.0        2               1        2              1
# 308    Male  62.0        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# 4.	Visualize the dataset using two appropriate plots

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    float64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
import seaborn as sns
sns.histplot(data=df[:100], x="AGE", color="red")


# plt.figure(figsize=(8,6))
# plt.hist(df['AGE'],bins=10)
# plt.xlabel('ANXIETY')
# plt.ylabel('LUNG_CANCER')
# plt.title('ANXIETY vs LUNG_CANCER')
# plt.show()
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %%
column_name = 'GENDER'
value_counts = df[column_name].value_counts()
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# 5.	Use any 2 out of 3 normalization methods to normalize two columns in the given data

# %%
columns_1=["AGE","CHEST PAIN"]
min_max_scaler=MinMaxScaler()
df_min_max=df.copy()
df_min_max[columns_1]=min_max_scaler.fit_transform(df[columns_1])
print("Min_Max_scaling:")
print(df_min_max[columns_1].head())
# Out:
# Min_Max_scaling:
#         AGE  CHEST PAIN
# 0  0.727273         1.0
# 1  0.803030         1.0
# 2  0.575758         1.0
# 3  0.636364         1.0
# 4  0.636364         0.0

# %% [markdown]
# 6.	Use any 2 out of 5 encoding methods to encode the data

# %%
Ordinal_Encoder=OrdinalEncoder()
df['gender_num']=Ordinal_Encoder.fit_transform(df[['GENDER']])

# %%
df
# Out:
#      GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1.0  69.0        1               2        2              1
# 1       1.0  74.0        2               1        1              1
# 2       0.0  59.0        1               1        1              2
# 3       1.0  63.0        2               2        2              1
# 4       0.0  63.0        1               2        1              1
# ..      ...   ...      ...             ...      ...            ...
# 304     0.0  56.0        1               1        1              2
# 305     1.0  70.0        2               1        1              1
# 306     1.0  58.0        2               1        1              1
# 307     1.0  67.0        2               1        2              1
# 308     1.0  62.0        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
gender = LabelEncoder()
df['count_encoder'] = gender.fit_transform(df['GENDER'])

# %%
df
# Out:
#      GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      Male  69.0        1               2        2              1
# 1      Male  74.0        2               1        1              1
# 2    Female  59.0        1               1        1              2
# 3      Male  63.0        2               2        2              1
# 4    Female  63.0        1               2        1              1
# ..      ...   ...      ...             ...      ...            ...
# 304  Female  56.0        1               1        1              2
# 305    Male  70.0        2               1        1              1
# 306    Male  58.0        2               1        1              1
# 307    Male  67.0        2               1        2              1
# 308    Male  62.0        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...
